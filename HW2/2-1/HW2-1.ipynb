# %%
import pandas as pd
import numpy as np
import statistics

# %%
origin_data = pd.read_csv('covid_19.csv',  usecols = lambda column : column not in ["Lat", "Long"], skiprows=[1, 2])
origin_data_numonly = pd.read_csv('covid_19.csv',  usecols = lambda column : column not in ["Lat", "Long", "Unnamed: 0"], skiprows=[1, 2])

# %%
country = origin_data['Unnamed: 0']

# %%
std = []
for i in range(len(country)):
    a = origin_data_numonly.iloc[i]
    v = statistics.stdev(a)
    std.append(v)

# %%
cor = []
for i in range(len(var) - 1):
    for j in range(i + 1, len(var), 1):
        list = []
        cov_mat = np.cov(origin_data_numonly.iloc[i], origin_data_numonly.iloc[j])
        cov = cov_mat[0, 1]
        c = cov / (std[i] * std[j])
        list.append(country[i])
        list.append(country[j])
        list.append(c)
        cor.append(list)

# %%
origin_data_numonly.iloc[0]

var[1]
cor
# Out:
# [['Afghanistan', 'Albania', 0.9680337134180618],
#  ['Afghanistan', 'Algeria', 0.995311273497437],
#  ['Afghanistan', 'Andorra', 0.9648978415576784],
#  ['Afghanistan', 'Angola', 0.988052973567041],
#  ['Afghanistan', 'Antigua and Barbuda', 0.9849498026524889],
#  ['Afghanistan', 'Argentina', 0.9889059027101608],
#  ['Afghanistan', 'Armenia', 0.9749227882146044],
#  ['Afghanistan', 'Australia', 0.9434776878577347],
#  ['Afghanistan', 'Austria', 0.9359269082992688],
#  ['Afghanistan', 'Azerbaijan', 0.9965458154675525],
#  ['Afghanistan', 'Bahamas', 0.996928222935128],
#  ['Afghanistan', 'Bahrain', 0.9412359635176796],
#  ['Afghanistan', 'Bangladesh', 0.8941845402958751],
#  ['Afghanistan', 'Barbados', 0.9777346562843703],
#  ['Afghanistan', 'Belarus', 0.9139800506299482],
#  ['Afghanistan', 'Belgium', 0.992060545333624],
#  ['Afghanistan', 'Belize', 0.978736353328164],
#  ['Afghanistan', 'Benin', 0.9924112618823127],
#  ['Afghanistan', 'Bhutan', 0.9014451149837787],
#  ['Afghanistan', 'Bolivia', 0.9961710870329997],
#  ['Afghanistan', 'Bosnia and Herzegovina', 0.9941523144385482],
#  ['Afghanistan', 'Botswana', 0.9550102470529057],
#  ['Afghanistan', 'Brazil', 0.9963886586512616],
#  ['Afghanistan', 'Brunei', 0.810597352934786],
#  ['Afghanistan', 'Bulgaria', 0.958008202359736],
#  ['Afghanistan', 'Burkina Faso', 0.9770297933236226],
#  ['Afghanistan', 'Burma', 0.9775318814687785],
#  ['Afghanistan', 'Burundi', 0.9556268154166381],
#  ['Afghanistan', 'Cabo Verde', 0.9091184139909501],
#  ['Afghanistan', 'Cambodia', 0.8398208798103926],
#  ['Afghanistan', 'Cameroon', 0.9853339031934522],
#  ['Afghanistan', 'Canada', 0.998488308971328],
#  ['Afghanistan', 'Central African Republic', 0.9375970431069642],
#  ['Afghanistan', 'Chad', 0.9820127047121434],
#  ['Afghanistan', 'Chile', 0.9968643372532048],
#  ['Afghanistan', 'China', 0.34193621095690485],
#  ['Afghanistan', 'Colombia', 0.9976424240917421],
#  ['Afghanistan', 'Congo (Brazzaville)', 0.9835915684194848],
#  ['Afghanistan', 'Congo (Kinshasa)', 0.9917356852195902],
#  ['Afghanistan', 'Costa Rica', 0.9601913106604737],
#  ['Afghanistan', "Cote d'Ivoire", 0.9940540541251677],
#  ['Afghanistan', 'Croatia', 0.9758267549990091],
#  ['Afghanistan', 'Cuba', 0.9955412400853623],
#  ['Afghanistan', 'Cyprus', 0.9905814840222151],
#  ['Afghanistan', 'Czechia', 0.9737776613741671],
#  ['Afghanistan', 'Denmark', 0.9734758661552002],
#  ['Afghanistan', 'Diamond Princess', 0.36043498116945827],
#  ['Afghanistan', 'Djibouti', 0.9591305201963178],
#  ['Afghanistan', 'Dominica', 0.9251136877152494],
#  ['Afghanistan', 'Dominican Republic', 0.9969824377716693],
#  ['Afghanistan', 'Ecuador', 0.9873011282813319],
#  ['Afghanistan', 'Egypt', 0.991418518970509],
#  ['Afghanistan', 'El Salvador', 0.9915667088144484],
#  ['Afghanistan', 'Equatorial Guinea', 0.9153057375005224],
#  ['Afghanistan', 'Eritrea', 0.9828487390804859],
#  ['Afghanistan', 'Estonia', 0.9581429518398473],
#  ['Afghanistan', 'Eswatini', 0.9269165417227074],
#  ['Afghanistan', 'Ethiopia', 0.99445257828111],
#  ['Afghanistan', 'Fiji', 0.9814449139640096],
#  ['Afghanistan', 'Finland', 0.9781304892771099],
#  ['Afghanistan', 'France', 0.9931504571732106],
#  ['Afghanistan', 'Gabon', 0.990747415831732],
#  ['Afghanistan', 'Gambia', 0.9111355911391839],
#  ['Afghanistan', 'Georgia', 0.9785635589389731],
#  ['Afghanistan', 'Germany', 0.9698133476142226],
#  ['Afghanistan', 'Ghana', 0.9826317436614148],
#  ['Afghanistan', 'Greece', 0.9475667360082765],
#  ['Afghanistan', 'Grenada', 0.9471506377628931],
#  ['Afghanistan', 'Guatemala', 0.9833664827770392],
#  ['Afghanistan', 'Guinea', 0.9669775155809499],
#  ['Afghanistan', 'Guinea-Bissau', 0.9744051426573507],
#  ['Afghanistan', 'Guyana', 0.9644753599201374],
#  ['Afghanistan', 'Haiti', 0.9875950818876112],
#  ['Afghanistan', 'Holy See', 0.9219421375797836],
#  ['Afghanistan', 'Honduras', 0.9947400351847399],
#  ['Afghanistan', 'Hungary', 0.9935834356043793],
#  ['Afghanistan', 'Iceland', 0.939804459290691],
#  ['Afghanistan', 'India', 0.9823800527414484],
#  ['Afghanistan', 'Indonesia', 0.9939382437082598],
#  ['Afghanistan', 'Iran', 0.942897726585148],
#  ['Afghanistan', 'Iraq', 0.9818972128552862],
#  ['Afghanistan', 'Ireland', 0.9938487931719383],
#  ['Afghanistan', 'Israel', 0.9866515113063825],
#  ['Afghanistan', 'Italy', 0.9204059831798644],
#  ['Afghanistan', 'Jamaica', 0.9582790096834852],
#  ['Afghanistan', 'Japan', 0.9816639981238897],
#  ['Afghanistan', 'Jordan', 0.9285041177983727],
#  ['Afghanistan', 'Kazakhstan', 0.9963001899649568],
#  ['Afghanistan', 'Kenya', 0.9936222960727504],
#  ['Afghanistan', 'Korea, South', 0.6317062871077479],
#  ['Afghanistan', 'Kosovo', 0.9806413453299982],
#  ['Afghanistan', 'Kuwait', 0.9812845296772725],
#  ['Afghanistan', 'Kyrgyzstan', 0.9922000551171214],
#  ['Afghanistan', 'Laos', 0.9805740022967045],
#  ['Afghanistan', 'Latvia', 0.95780587495537],
#  ['Afghanistan', 'Lebanon', 0.90776936947816],
#  ['Afghanistan', 'Liberia', 0.92162718267742],
#  ['Afghanistan', 'Libya', 0.9857500103408813],
#  ['Afghanistan', 'Liechtenstein', 0.8751875175686713],
#  ['Afghanistan', 'Lithuania', 0.981195469116389],
#  ['Afghanistan', 'Luxembourg', 0.9487481790541672],
#  ['Afghanistan', 'MS Zaandam', 0.9404576301527757],
#  ['Afghanistan', 'Madagascar', 0.9866794135372687],
#  ['Afghanistan', 'Malawi', 0.9374662245828459],
#  ['Afghanistan', 'Malaysia', 0.951812167867036],
#  ['Afghanistan', 'Maldives', 0.7720702317667333],
#  ['Afghanistan', 'Mali', 0.9880377534077832],
#  ['Afghanistan', 'Malta', 0.9738067111718527],
#  ['Afghanistan', 'Mauritania', 0.9203778309815129],
#  ['Afghanistan', 'Mauritius', 0.9923982407643345],
#  ['Afghanistan', 'Mexico', 0.9941258280051323],
#  ['Afghanistan', 'Moldova', 0.9927559308113665],
#  ['Afghanistan', 'Monaco', 0.9687134510292578],
#  ['Afghanistan', 'Mongolia', 0.8652006200387806],
#  ['Afghanistan', 'Montenegro', 0.9882824348525749],
#  ['Afghanistan', 'Morocco', 0.9973196399767449],
#  ['Afghanistan', 'Mozambique', 0.9744867232331103],
#  ['Afghanistan', 'Namibia', 0.9370280865724651],
#  ['Afghanistan', 'Nepal', 0.9732640717567768],
#  ['Afghanistan', 'Netherlands', 0.9811365680822297],
#  ['Afghanistan', 'New Zealand', 0.9868976804164216],
#  ['Afghanistan', 'Nicaragua', 0.9656117832339066],
#  ['Afghanistan', 'Niger', 0.9544594261250111],
#  ['Afghanistan', 'Nigeria', 0.9917714040596581],
#  ['Afghanistan', 'North Macedonia', 0.9922132273709127],
#  ['Afghanistan', 'Norway', 0.9186166274810263],
#  ['Afghanistan', 'Oman', 0.9951391206925261],
#  ['Afghanistan', 'Pakistan', 0.9934102833966088],
#  ['Afghanistan', 'Panama', 0.9968995850284996],
#  ['Afghanistan', 'Papua New Guinea', 0.9082086848504376],
#  ['Afghanistan', 'Paraguay', 0.9799259430815356],
#  ['Afghanistan', 'Peru', 0.9577723680375064],
#  ['Afghanistan', 'Philippines', 0.9919199261032997],
#  ['Afghanistan', 'Poland', 0.9979480388015958],
#  ['Afghanistan', 'Portugal', 0.9915260549326962],
#  ['Afghanistan', 'Qatar', 0.9810857789033811],
#  ['Afghanistan', 'Romania', 0.9977339919734367],
#  ['Afghanistan', 'Russia', 0.9721918078207985],
#  ['Afghanistan', 'Rwanda', 0.9579689748512318],
#  ['Afghanistan', 'Saint Kitts and Nevis', 0.9719999081012355],
#  ['Afghanistan', 'Saint Lucia', 0.946207562507948],
#  ['Afghanistan', 'Saint Vincent and the Grenadines', 0.9567239115355128],
#  ['Afghanistan', 'San Marino', 0.8795267890518383],
#  ['Afghanistan', 'Sao Tome and Principe', 0.8514139665568488],
#  ['Afghanistan', 'Saudi Arabia', 0.9934644932024401],
#  ['Afghanistan', 'Senegal', 0.9595034208582934],
#  ['Afghanistan', 'Serbia', 0.9958928508517508],
#  ['Afghanistan', 'Seychelles', 0.8509111035847821],
#  ['Afghanistan', 'Sierra Leone', 0.9600759867209793],
#  ['Afghanistan', 'Singapore', 0.9820018101496231],
#  ['Afghanistan', 'Slovakia', 0.9752086463759031],
#  ['Afghanistan', 'Slovenia', 0.9298735622855812],
#  ['Afghanistan', 'Somalia', 0.9499854848271982],
#  ['Afghanistan', 'South Africa', 0.9517358997941404],
#  ['Afghanistan', 'South Sudan', 0.8643410666316167],
#  ['Afghanistan', 'Spain', 0.9705497447908877],
#  ['Afghanistan', 'Sri Lanka', 0.9187735888022305],
#  ['Afghanistan', 'Sudan', 0.9945121147080793],
#  ['Afghanistan', 'Suriname', 0.8646297004327678],
#  ['Afghanistan', 'Sweden', 0.9859993511014713],
#  ['Afghanistan', 'Switzerland', 0.9423234147235536],
#  ['Afghanistan', 'Syria', 0.983588253656359],
#  ['Afghanistan', 'Taiwan*', 0.8948921690692669],
#  ['Afghanistan', 'Tanzania', 0.9494324065228888],
#  ['Afghanistan', 'Thailand', 0.9578909182947757],
#  ['Afghanistan', 'Timor-Leste', 0.8792895198333038],
#  ['Afghanistan', 'Togo', 0.9832250667417407],
#  ['Afghanistan', 'Trinidad and Tobago', 0.9087861924374877],
#  ['Afghanistan', 'Tunisia', 0.9786234063343002],
#  ['Afghanistan', 'Turkey', 0.992002401613394],
#  ['Afghanistan', 'US', 0.9984820260747108],
#  ['Afghanistan', 'Uganda', 0.9466643718198702],
#  ['Afghanistan', 'Ukraine', 0.9912151218943716],
#  ['Afghanistan', 'United Arab Emirates', 0.9839659767479312],
#  ['Afghanistan', 'United Kingdom', 0.9987686454183906],
#  ['Afghanistan', 'Uruguay', 0.9411533518150804],
#  ['Afghanistan', 'Uzbekistan', 0.9833392843339186],
#  ['Afghanistan', 'Venezuela', 0.9087994527947786],
#  ['Afghanistan', 'Vietnam', 0.9026260858825172],
#  ['Afghanistan', 'West Bank and Gaza', 0.9772899392429624],
#  ['Afghanistan', 'Western Sahara', 0.8845708640365232],
#  ['Afghanistan', 'Yemen', 0.6421638743855744],
#  ['Afghanistan', 'Zambia', 0.9243991228977245],
#  ['Afghanistan', 'Zimbabwe', 0.9671614323524819],
#  ['Albania', 'Algeria', 0.9809221494186809],
#  ['Albania', 'Andorra', 0.9954558586647428],
#  ['Albania', 'Angola', 0.9704692114670932],
#  ['Albania', 'Antigua and Barbuda', 0.979948710766695],
#  ['Albania', 'Argentina', 0.9901104869022886],
#  ['Albania', 'Armenia', 0.9965027853416661],
#  ['Albania', 'Australia', 0.9920540289819455],
#  ['Albania', 'Austria', 0.9910668817514326],
#  ['Albania', 'Azerbaijan', 0.9520997106982383],
#  ['Albania', 'Bahamas', 0.9722332641264366],
#  ['Albania', 'Bahrain', 0.9813644077209592],
#  ['Albania', 'Bangladesh', 0.795758468826705],
#  ['Albania', 'Barbados', 0.9925209297564924],
#  ['Albania', 'Belarus', 0.8089178089713825],
#  ['Albania', 'Belgium', 0.9886339256476587],
#  ['Albania', 'Belize', 0.920187288713712],
#  ['Albania', 'Benin', 0.9569484437019334],
#  ['Albania', 'Bhutan', 0.9700967005133125],
#  ['Albania', 'Bolivia', 0.9688826660278913],
#  ['Albania', 'Bosnia and Herzegovina', 0.9860622851949268],
#  ['Albania', 'Botswana', 0.8725054526309322],
#  ['Albania', 'Brazil', 0.9529648414155821],
#  ['Albania', 'Brunei', 0.9235841654054857],
#  ['Albania', 'Bulgaria', 0.9974490623966003],
#  ['Albania', 'Burkina Faso', 0.9946157754370942],
#  ['Albania', 'Burma', 0.9441863211730918],
#  ['Albania', 'Burundi', 0.9024488187731202],
#  ['Albania', 'Cabo Verde', 0.9741636900999271],
#  ['Albania', 'Cambodia', 0.9395745468965412],
#  ['Albania', 'Cameroon', 0.9453904105866142],
#  ['Albania', 'Canada', 0.9737846879717503],
#  ['Albania', 'Central African Republic', 0.9686993174835151],
#  ['Albania', 'Chad', 0.9677360155653861],
#  ['Albania', 'Chile', 0.9805052153250717],
#  ['Albania', 'China', 0.410486022981265],
#  ['Albania', 'Colombia', 0.969784563906915],
#  ['Albania', 'Congo (Brazzaville)', 0.9388507333234742],
#  ['Albania', 'Congo (Kinshasa)', 0.9855125384767799],
#  ['Albania', 'Costa Rica', 0.9969654795200532],
#  ['Albania', "Cote d'Ivoire", 0.9589580047001276],
#  ['Albania', 'Croatia', 0.9958986597186698],
#  ['Albania', 'Cuba', 0.9496228959186382],
#  ['Albania', 'Cyprus', 0.9907425393499396],
#  ['Albania', 'Czechia', 0.9978092035861998],
#  ['Albania', 'Denmark', 0.9951666905693921],
#  ['Albania', 'Diamond Princess', 0.43640687160076824],
#  ['Albania', 'Djibouti', 0.8731414841869151],
#  ['Albania', 'Dominica', 0.9736065412677647],
#  ['Albania', 'Dominican Republic', 0.9736054275816918],
#  ['Albania', 'Ecuador', 0.9583903608565726],
#  ['Albania', 'Egypt', 0.9835084831471029],
#  ['Albania', 'El Salvador', 0.9374714586826366],
#  ['Albania', 'Equatorial Guinea', 0.9793420296184132],
#  ['Albania', 'Eritrea', 0.9676657790698241],
#  ['Albania', 'Estonia', 0.9981032460913895],
#  ['Albania', 'Eswatini', 0.9788200739125492],
#  ['Albania', 'Ethiopia', 0.9792661649760774],
#  ['Albania', 'Fiji', 0.9751365431442804],
#  ['Albania', 'Finland', 0.9956434942920805],
#  ['Albania', 'France', 0.9848470677094805],
#  ['Albania', 'Gabon', 0.945190813562812],
#  ['Albania', 'Gambia', 0.9393702205733271],
#  ['Albania', 'Georgia', 0.9936728380237626],
#  ['Albania', 'Germany', 0.9982186666405004],
#  ['Albania', 'Ghana', 0.957860882228292],
#  ['Albania', 'Greece', 0.9955822557750031],
#  ['Albania', 'Grenada', 0.9760773269456916],
#  ['Albania', 'Guatemala', 0.9474441536993968],
#  ['Albania', 'Guinea', 0.8841888935525373],
#  ['Albania', 'Guinea-Bissau', 0.9033096874905389],
#  ['Albania', 'Guyana', 0.945530226867166],
#  ['Albania', 'Haiti', 0.9836942836426029],
#  ['Albania', 'Holy See', 0.978165749504018],
#  ['Albania', 'Honduras', 0.9731994266022914],
#  ['Albania', 'Hungary', 0.9730873571593937],
#  ['Albania', 'Iceland', 0.9939495144198862],
#  ['Albania', 'India', 0.9139893065440953],
#  ['Albania', 'Indonesia', 0.9820423370025593],
#  ['Albania', 'Iran', 0.9911399573846285],
#  ['Albania', 'Iraq', 0.9959283162940248],
#  ['Albania', 'Ireland', 0.9730116602119897],
#  ['Albania', 'Israel', 0.9883405797409865],
#  ['Albania', 'Italy', 0.9856937017837546],
#  ['Albania', 'Jamaica', 0.9968180945392361],
#  ['Albania', 'Japan', 0.9627193640117051],
#  ['Albania', 'Jordan', 0.9882685807704104],
#  ['Albania', 'Kazakhstan', 0.9729222623518596],
#  ['Albania', 'Kenya', 0.9676321184464057],
#  ['Albania', 'Korea, South', 0.739816556808194],
#  ['Albania', 'Kosovo', 0.9562460755058902],
#  ['Albania', 'Kuwait', 0.944701390743534],
#  ['Albania', 'Kyrgyzstan', 0.9466840942109361],
#  ['Albania', 'Laos', 0.9776723425238794],
#  ['Albania', 'Latvia', 0.9966852122491537],
#  ['Albania', 'Lebanon', 0.9804590349536103],
#  ['Albania', 'Liberia', 0.8277125887070533],
#  ['Albania', 'Libya', 0.9497476860305332],
#  ['Albania', 'Liechtenstein', 0.9611864115436468],
#  ['Albania', 'Lithuania', 0.9933655722695002],
#  ['Albania', 'Luxembourg', 0.993486394151866],
#  ['Albania', 'MS Zaandam', 0.9217731034184932],
#  ['Albania', 'Madagascar', 0.9829778427071528],
#  ['Albania', 'Malawi', 0.8344965617347594],
#  ['Albania', 'Malaysia', 0.996473440037973],
#  ['Albania', 'Maldives', 0.8824734585065063],
#  ['Albania', 'Mali', 0.9304478764354092],
#  ['Albania', 'Malta', 0.9908510668228839],
#  ['Albania', 'Mauritania', 0.9802944451162459],
#  ['Albania', 'Mauritius', 0.9826653528626778],
#  ['Albania', 'Mexico', 0.9474153170497553],
#  ['Albania', 'Moldova', 0.9407955160926567],
#  ['Albania', 'Monaco', 0.9972042016319423],
#  ['Albania', 'Mongolia', 0.9531056007914931],
#  ['Albania', 'Montenegro', 0.9835700550422428],
#  ['Albania', 'Morocco', 0.9768001444864215],
#  ['Albania', 'Mozambique', 0.9637810251780697],
#  ['Albania', 'Namibia', 0.9901316710674254],
#  ['Albania', 'Nepal', 0.9759082621535038],
#  ['Albania', 'Netherlands', 0.9966468666363861],
#  ['Albania', 'New Zealand', 0.9848568623523353],
#  ['Albania', 'Nicaragua', 0.9855268345856915],
#  ['Albania', 'Niger', 0.8589690584169248],
#  ['Albania', 'Nigeria', 0.9836548795879195],
#  ['Albania', 'North Macedonia', 0.9887857848939421],
#  ['Albania', 'Norway', 0.9862283854330036],
#  ['Albania', 'Oman', 0.9721265746235719],
#  ['Albania', 'Pakistan', 0.9846313518857692],
#  ['Albania', 'Panama', 0.9749325344656755],
#  ['Albania', 'Papua New Guinea', 0.9471165057791225],
#  ['Albania', 'Paraguay', 0.9967999765846918],
#  ['Albania', 'Peru', 0.87748447354657],
#  ['Albania', 'Philippines', 0.9802309417373039],
#  ['Albania', 'Poland', 0.9780875495770356],
#  ['Albania', 'Portugal', 0.9875516829086156],
#  ['Albania', 'Qatar', 0.9583914698213928],
#  ['Albania', 'Romania', 0.9773160337552498],
#  ['Albania', 'Russia', 0.8933569184947618],
#  ['Albania', 'Rwanda', 0.994980805388454],
#  ['Albania', 'Saint Kitts and Nevis', 0.9614280000734622],
#  ['Albania', 'Saint Lucia', 0.9742149091469905],
#  ['Albania', 'Saint Vincent and the Grenadines', 0.8921885680093408],
#  ['Albania', 'San Marino', 0.9556369825491913],
#  ['Albania', 'Sao Tome and Principe', 0.7520254293024784],
#  ['Albania', 'Saudi Arabia', 0.9812735753502688],
#  ['Albania', 'Senegal', 0.9967740683199993],
#  ['Albania', 'Serbia', 0.9518779472642479],
#  ['Albania', 'Seychelles', 0.9434916000291986],
#  ['Albania', 'Sierra Leone', 0.8771702114661906],
#  ['Albania', 'Singapore', 0.9774515322968759],
#  ['Albania', 'Slovakia', 0.994298093850034],
#  ['Albania', 'Slovenia', 0.9898490136394346],
#  ['Albania', 'Somalia', 0.8771533790354727],
#  ['Albania', 'South Africa', 0.9909892467721643],
#  ['Albania', 'South Sudan', 0.7397607163486786],
#  ['Albania', 'Spain', 0.9979442400633899],
#  ['Albania', 'Sri Lanka', 0.982589005241322],
#  ['Albania', 'Sudan', 0.9772189182269095],
#  ['Albania', 'Suriname', 0.9550057665883499],
#  ['Albania', 'Sweden', 0.9926836510861377],
#  ['Albania', 'Switzerland', 0.9938637797308121],
#  ['Albania', 'Syria', 0.9733636713893834],
#  ['Albania', 'Taiwan*', 0.9736411052683707],
#  ['Albania', 'Tanzania', 0.9855530134275323],
#  ['Albania', 'Thailand', 0.9958280405672048],
#  ['Albania', 'Timor-Leste', 0.9194164506347317],
#  ['Albania', 'Togo', 0.9834240413919376],
#  ['Albania', 'Trinidad and Tobago', 0.9762299159880662],
#  ['Albania', 'Tunisia', 0.9927499964359078],
#  ['Albania', 'Turkey', 0.9338893832690365],
#  ['Albania', 'US', 0.9708718434118626],
#  ['Albania', 'Uganda', 0.9786311816886967],
#  ['Albania', 'Ukraine', 0.9356199815033599],
#  ['Albania', 'United Arab Emirates', 0.9189366104023429],
#  ['Albania', 'United Kingdom', 0.9659553460669243],
#  ['Albania', 'Uruguay', 0.9909832292535975],
#  ['Albania', 'Uzbekistan', 0.922758275299118],
#  ['Albania', 'Venezuela', 0.9800638274584191],
#  ['Albania', 'Vietnam', 0.9780953569930407],
#  ['Albania', 'West Bank and Gaza', 0.990915473438732],
#  ['Albania', 'Western Sahara', 0.7902099376767837],
#  ['Albania', 'Yemen', 0.5126020214471698],
#  ['Albania', 'Zambia', 0.9700061046198616],
#  ['Albania', 'Zimbabwe', 0.9864923593517656],
#  ['Algeria', 'Andorra', 0.9784685760253481],
#  ['Algeria', 'Angola', 0.9887543233711438],
#  ['Algeria', 'Antigua and Barbuda', 0.9915953686391589],
#  ['Algeria', 'Argentina', 0.9961244087131625],
#  ['Algeria', 'Armenia', 0.9883453800859193],
#  ['Algeria', 'Australia', 0.9629229978432288],
#  ['Algeria', 'Austria', 0.9551335831236637],
#  ['Algeria', 'Azerbaijan', 0.9883813853882776],
#  ['Algeria', 'Bahamas', 0.9961871145047062],
#  ['Algeria', 'Bahrain', 0.9495764432054294],
#  ['Algeria', 'Bangladesh', 0.8553726577924199],
#  ['Algeria', 'Barbados', 0.9901776733615647],
#  ['Algeria', 'Belarus', 0.878660934001128],
#  ['Algeria', 'Belgium', 0.9967825667277829],
#  ['Algeria', 'Belize', 0.9608343815468561],
#  ['Algeria', 'Benin', 0.9877350708442758],
#  ['Algeria', 'Bhutan', 0.9262219936866801],
#  ['Algeria', 'Bolivia', 0.9914974350645774],
#  ['Algeria', 'Bosnia and Herzegovina', 0.9980212648759305],
#  ['Algeria', 'Botswana', 0.934575095484947],
#  ['Algeria', 'Brazil', 0.9882943975981515],
#  ['Algeria', 'Brunei', 0.8370363461983608],
#  ['Algeria', 'Bulgaria', 0.972646453521177],
#  ['Algeria', 'Burkina Faso', 0.9856192770516887],
#  ['Algeria', 'Burma', 0.9743848897645294],
#  ['Algeria', 'Burundi', 0.9551301962622598],
#  ['Algeria', 'Cabo Verde', 0.9309937850287482],
#  ['Algeria', 'Cambodia', 0.86621405384107],
#  ['Algeria', 'Cameroon', 0.9873458655440607],
#  ['Algeria', 'Canada', 0.9977382896349373],
#  ['Algeria', 'Central African Republic', 0.9582251590788682],
#  ['Algeria', 'Chad', 0.9823309770138571],
#  ['Algeria', 'Chile', 0.9978013992061758],
#  ['Algeria', 'China', 0.3547227449360444],
#  ['Algeria', 'Colombia', 0.99313808549769],
#  ['Algeria', 'Congo (Brazzaville)', 0.9761974244768283],
#  ['Algeria', 'Congo (Kinshasa)', 0.996762430524839],
#  ['Algeria', 'Costa Rica', 0.9739362100068657],
#  ['Algeria', "Cote d'Ivoire", 0.9857964442030904],
#  ['Algeria', 'Croatia', 0.9868416050848484],
#  ['Algeria', 'Cuba', 0.9862006886280013],
#  ['Algeria', 'Cyprus', 0.9970968362535776],
#  ['Algeria', 'Czechia', 0.9860110897312424],
#  ['Algeria', 'Denmark', 0.9816311290883063],
#  ['Algeria', 'Diamond Princess', 0.374456852735719],
#  ['Algeria', 'Djibouti', 0.9344131757221597],
#  ['Algeria', 'Dominica', 0.9429886608278232],
#  ['Algeria', 'Dominican Republic', 0.9955626389117257],
#  ['Algeria', 'Ecuador', 0.9810813490496718],
#  ['Algeria', 'Egypt', 0.990640483901078],
#  ['Algeria', 'El Salvador', 0.980871780771451],
#  ['Algeria', 'Equatorial Guinea', 0.9343400168225946],
#  ['Algeria', 'Eritrea', 0.9920652200081626],
#  ['Algeria', 'Estonia', 0.9729596925861722],
#  ['Algeria', 'Eswatini', 0.9410690638261628],
#  ['Algeria', 'Ethiopia', 0.9934882636067307],
#  ['Algeria', 'Fiji', 0.9863036732225252],
#  ['Algeria', 'Finland', 0.9843991678257429],
#  ['Algeria', 'France', 0.9966393017255251],
#  ['Algeria', 'Gabon', 0.9812171013170414],
#  ['Algeria', 'Gambia', 0.9116755562260102],
#  ['Algeria', 'Georgia', 0.9851593013280843],
#  ['Algeria', 'Germany', 0.9829737646259277],
#  ['Algeria', 'Ghana', 0.9729217077119316],
#  ['Algeria', 'Greece', 0.9636291660748469],
#  ['Algeria', 'Grenada', 0.964116320304532],
#  ['Algeria', 'Guatemala', 0.9717884856641409],
#  ['Algeria', 'Guinea', 0.9495767287693707],
#  ['Algeria', 'Guinea-Bissau', 0.960041345343029],
#  ['Algeria', 'Guyana', 0.9648303478480829],
#  ['Algeria', 'Haiti', 0.9913617997727098],
#  ['Algeria', 'Holy See', 0.9403771532349177],
#  ['Algeria', 'Honduras', 0.9976482603581435],
#  ['Algeria', 'Hungary', 0.9894473674468925],
#  ['Algeria', 'Iceland', 0.9584966688083516],
#  ['Algeria', 'India', 0.9646602316379428],
#  ['Algeria', 'Indonesia', 0.9924298590493894],
#  ['Algeria', 'Iran', 0.9580990560219957],
#  ['Algeria', 'Iraq', 0.9892537092607397],
#  ['Algeria', 'Ireland', 0.9900018866262156],
#  ['Algeria', 'Israel', 0.995443860304284],
#  ['Algeria', 'Italy', 0.9387447461041337],
#  ['Algeria', 'Jamaica', 0.9720046396323172],
#  ['Algeria', 'Japan', 0.9746689185322508],
#  ['Algeria', 'Jordan', 0.9481497494222971],
#  ['Algeria', 'Kazakhstan', 0.9966222742750669],
#  ['Algeria', 'Kenya', 0.9965975016514917],
#  ['Algeria', 'Korea, South', 0.6534048069318873],
#  ['Algeria', 'Kosovo', 0.9757807747128193],
#  ['Algeria', 'Kuwait', 0.9695435160184451],
#  ['Algeria', 'Kyrgyzstan', 0.9811861995212613],
#  ['Algeria', 'Laos', 0.9822571277284562],
#  ['Algeria', 'Latvia', 0.9736770369291635],
#  ['Algeria', 'Lebanon', 0.9276352445839505],
#  ['Algeria', 'Liberia', 0.8898302640647321],
#  ['Algeria', 'Libya', 0.9866255092703736],
#  ['Algeria', 'Liechtenstein', 0.9011961684102962],
#  ['Algeria', 'Lithuania', 0.9917597334033474],
#  ['Algeria', 'Luxembourg', 0.9665459506652044],
#  ['Algeria', 'MS Zaandam', 0.9543431724308057],
#  ['Algeria', 'Madagascar', 0.9941637420578127],
#  ['Algeria', 'Malawi', 0.9111451487191711],
#  ['Algeria', 'Malaysia', 0.9665780180277868],
#  ['Algeria', 'Maldives', 0.7954645106657692],
#  ['Algeria', 'Mali', 0.9752574775885178],
#  ['Algeria', 'Malta', 0.9778644721210271],
#  ['Algeria', 'Mauritania', 0.9406759928563262],
#  ['Algeria', 'Mauritius', 0.9961367213634855],
#  ['Algeria', 'Mexico', 0.98290762166707],
#  ['Algeria', 'Moldova', 0.982642001723277],
#  ['Algeria', 'Monaco', 0.9811856813716697],
#  ['Algeria', 'Mongolia', 0.888806815645114],
#  ['Algeria', 'Montenegro', 0.996718469007339],
#  ['Algeria', 'Morocco', 0.997056647917339],
#  ['Algeria', 'Mozambique', 0.9708195819990874],
#  ['Algeria', 'Namibia', 0.9565156605237964],
#  ['Algeria', 'Nepal', 0.9822139449255974],
#  ['Algeria', 'Netherlands', 0.9895253113304198],
#  ['Algeria', 'New Zealand', 0.9953056429267815],
#  ['Algeria', 'Nicaragua', 0.9749395697961033],
#  ['Algeria', 'Niger', 0.9298274725371394],
#  ['Algeria', 'Nigeria', 0.9978109165987116],
#  ['Algeria', 'North Macedonia', 0.9960849816246987],
#  ['Algeria', 'Norway', 0.9383703303437174],
#  ['Algeria', 'Oman', 0.9898959954770279],
#  ['Algeria', 'Pakistan', 0.9950820284759775],
#  ['Algeria', 'Panama', 0.9950461889543161],
#  ['Algeria', 'Papua New Guinea', 0.9174962027350978],
#  ['Algeria', 'Paraguay', 0.9905474405704208],
#  ['Algeria', 'Peru', 0.9317860967691866],
#  ['Algeria', 'Philippines', 0.9983263354488303],
#  ['Algeria', 'Poland', 0.9975610188390623],
#  ['Algeria', 'Portugal', 0.9968733409196564],
#  ['Algeria', 'Qatar', 0.9736231918178875],
#  ['Algeria', 'Romania', 0.9974839793486199],
#  ['Algeria', 'Russia', 0.9504870939024241],
#  ['Algeria', 'Rwanda', 0.9739108430728869],
#  ['Algeria', 'Saint Kitts and Nevis', 0.9801276216760908],
#  ['Algeria', 'Saint Lucia', 0.9645448553300341],
#  ['Algeria', 'Saint Vincent and the Grenadines', 0.9433468765546288],
#  ['Algeria', 'San Marino', 0.8946206431455952],
#  ['Algeria', 'Sao Tome and Principe', 0.823210963675607],
#  ['Algeria', 'Saudi Arabia', 0.9915449519916202],
#  ['Algeria', 'Senegal', 0.9743489824926255],
#  ['Algeria', 'Serbia', 0.9881786244584233],
#  ['Algeria', 'Seychelles', 0.8754826433981099],
#  ['Algeria', 'Sierra Leone', 0.94450493097609],
#  ['Algeria', 'Singapore', 0.9786518810960241],
#  ['Algeria', 'Slovakia', 0.9825863134450176],
#  ['Algeria', 'Slovenia', 0.9473532225233242],
#  ['Algeria', 'Somalia', 0.926357678197604],
#  ['Algeria', 'South Africa', 0.9657775563464597],
#  ['Algeria', 'South Sudan', 0.8214682441864672],
#  ['Algeria', 'Spain', 0.9837329845065816],
#  ['Algeria', 'Sri Lanka', 0.9377645196845192],
#  ['Algeria', 'Sudan', 0.9935838563724005],
#  ['Algeria', 'Suriname', 0.8912129537478181],
#  ['Algeria', 'Sweden', 0.9906277354004854],
#  ['Algeria', 'Switzerland', 0.9597960890105545],
#  ['Algeria', 'Syria', 0.9899446049897394],
#  ['Algeria', 'Taiwan*', 0.9184874013274011],
#  ['Algeria', 'Tanzania', 0.9603168569440331],
#  ['Algeria', 'Thailand', 0.9743420285578828],
#  ['Algeria', 'Timor-Leste', 0.8849635408191906],
#  ['Algeria', 'Togo', 0.9861558550931635],
#  ['Algeria', 'Trinidad and Tobago', 0.9323298049500096],
#  ['Algeria', 'Tunisia', 0.9910297365657654],
#  ['Algeria', 'Turkey', 0.9804526374959807],
#  ['Algeria', 'US', 0.9973137578982426],
#  ['Algeria', 'Uganda', 0.9661160138385149],
#  ['Algeria', 'Ukraine', 0.9800134934100305],
#  ['Algeria', 'United Arab Emirates', 0.9677639064847858],
#  ['Algeria', 'United Kingdom', 0.9945511029927],
#  ['Algeria', 'Uruguay', 0.9592439220789689],
#  ['Algeria', 'Uzbekistan', 0.9668927256688341],
#  ['Algeria', 'Venezuela', 0.9306486857224894],
#  ['Algeria', 'Vietnam', 0.9251014367004418],
#  ['Algeria', 'West Bank and Gaza', 0.9881984152448998],
#  ['Algeria', 'Western Sahara', 0.8584450111173473],
#  ['Algeria', 'Yemen', 0.5899699566096275],
#  ['Algeria', 'Zambia', 0.9450273789266466],
#  ['Algeria', 'Zimbabwe', 0.9774087034484853],
#  ['Andorra', 'Angola', 0.9694352508632593],
#  ['Andorra', 'Antigua and Barbuda', 0.9753045517245602],
#  ['Andorra', 'Argentina', 0.9908510429671619],
#  ['Andorra', 'Armenia', 0.9963154724542308],
#  ['Andorra', 'Australia', 0.9963102997408715],
#  ['Andorra', 'Austria', 0.9938814603135302],
#  ['Andorra', 'Azerbaijan', 0.9481297147685179],
#  ['Andorra', 'Bahamas', 0.9705053169960322],
#  ['Andorra', 'Bahrain', 0.9677374450366356],
#  ['Andorra', 'Bangladesh', 0.7878381583438137],
#  ['Andorra', 'Barbados', 0.9945927162547595],
#  ['Andorra', 'Belarus', 0.7991292502758318],
#  ['Andorra', 'Belgium', 0.9886018152003787],
#  ['Andorra', 'Belize', 0.9165079035098478],
#  ['Andorra', 'Benin', 0.9501594010841876],
#  ['Andorra', 'Bhutan', 0.9668778589233967],
#  ['Andorra', 'Bolivia', 0.9675938881927709],
#  ['Andorra', 'Bosnia and Herzegovina', 0.9854709666342558],
#  ['Andorra', 'Botswana', 0.870513072510581],
#  ['Andorra', 'Brazil', 0.9492859643848643],
#  ['Andorra', 'Brunei', 0.910833225668445],
#  ['Andorra', 'Bulgaria', 0.9958665997947561],
#  ['Andorra', 'Burkina Faso', 0.9974706003548327],
#  ['Andorra', 'Burma', 0.9495613284012591],
#  ['Andorra', 'Burundi', 0.8988778857246971],
#  ['Andorra', 'Cabo Verde', 0.9818975589941594],
#  ['Andorra', 'Cambodia', 0.9394654016217977],
#  ['Andorra', 'Cameroon', 0.9389008699745935],
#  ['Andorra', 'Canada', 0.9723941056096382],
#  ['Andorra', 'Central African Republic', 0.9563708594776826],
#  ['Andorra', 'Chad', 0.9695081232915047],
#  ['Andorra', 'Chile', 0.9799958573498959],
#  ['Andorra', 'China', 0.38827462186295114],
#  ['Andorra', 'Colombia', 0.9677669570469457],
#  ['Andorra', 'Congo (Brazzaville)', 0.9359519578107772],
#  ['Andorra', 'Congo (Kinshasa)', 0.9853647289583608],
#  ['Andorra', 'Costa Rica', 0.9979811324899459],
#  ['Andorra', "Cote d'Ivoire", 0.9586780318279415],
#  ['Andorra', 'Croatia', 0.9982015667346881],
#  ['Andorra', 'Cuba', 0.9482285039178118],
#  ['Andorra', 'Cyprus', 0.9873876732893674],
#  ['Andorra', 'Czechia', 0.9982553701129055],
#  ['Andorra', 'Denmark', 0.9847919696534732],
#  ['Andorra', 'Diamond Princess', 0.4116887056461978],
#  ['Andorra', 'Djibouti', 0.8667274054833576],
#  ['Andorra', 'Dominica', 0.9825616549774432],
#  ['Andorra', 'Dominican Republic', 0.9749926789041024],
#  ['Andorra', 'Ecuador', 0.958018661410482],
#  ['Andorra', 'Egypt', 0.9761998141482041],
#  ['Andorra', 'El Salvador', 0.9353786012964974],
#  ['Andorra', 'Equatorial Guinea', 0.979050922175348],
#  ['Andorra', 'Eritrea', 0.9682996315828055],
#  ['Andorra', 'Estonia', 0.992476319377961],
#  ['Andorra', 'Eswatini', 0.9851601815051995],
#  ['Andorra', 'Ethiopia', 0.9746974777467192],
#  ['Andorra', 'Fiji', 0.9705595697996051],
#  ['Andorra', 'Finland', 0.9907958363514321],
#  ['Andorra', 'France', 0.9802268243377412],
#  ['Andorra', 'Gabon', 0.9410660928549855],
#  ['Andorra', 'Gambia', 0.9410328988150962],
#  ['Andorra', 'Georgia', 0.9838175924908407],
#  ['Andorra', 'Germany', 0.9985447326825123],
#  ['Andorra', 'Ghana', 0.9598773860775507],
#  ['Andorra', 'Greece', 0.9902212210779826],
#  ['Andorra', 'Grenada', 0.9853108780919095],
#  ['Andorra', 'Guatemala', 0.9434502600675375],
#  ['Andorra', 'Guinea', 0.8750979108558969],
#  ['Andorra', 'Guinea-Bissau', 0.8981039785698691],
#  ['Andorra', 'Guyana', 0.9322367423487062],
#  ['Andorra', 'Haiti', 0.9864075932869633],
#  ['Andorra', 'Holy See', 0.9809381471988077],
#  ['Andorra', 'Honduras', 0.9732329320557662],
#  ['Andorra', 'Hungary', 0.9718687392244871],
#  ['Andorra', 'Iceland', 0.9919054834295263],
#  ['Andorra', 'India', 0.9072580042674319],
#  ['Andorra', 'Indonesia', 0.9799604320721238],
#  ['Andorra', 'Iran', 0.981592086023298],
#  ['Andorra', 'Iraq', 0.9918157125202944],
#  ['Andorra', 'Ireland', 0.9716056324140419],
#  ['Andorra', 'Israel', 0.9902822532616224],
#  ['Andorra', 'Italy', 0.9795538327781179],
#  ['Andorra', 'Jamaica', 0.9891113702361999],
#  ['Andorra', 'Japan', 0.9504519909492047],
#  ['Andorra', 'Jordan', 0.9915358397525912],
#  ['Andorra', 'Kazakhstan', 0.9727449090340171],
#  ['Andorra', 'Kenya', 0.964504985337638],
#  ['Andorra', 'Korea, South', 0.7084131453006645],
#  ['Andorra', 'Kosovo', 0.9612620381891214],
#  ['Andorra', 'Kuwait', 0.9312506017816267],
#  ['Andorra', 'Kyrgyzstan', 0.9453233270502758],
#  ['Andorra', 'Laos', 0.9840933417536858],
#  ['Andorra', 'Latvia', 0.9979250259395275],
#  ['Andorra', 'Lebanon', 0.9763010097355985],
#  ['Andorra', 'Liberia', 0.8167351510715392],
#  ['Andorra', 'Libya', 0.9501677375115457],
#  ['Andorra', 'Liechtenstein', 0.9603729075399706],
#  ['Andorra', 'Lithuania', 0.995996017731177],
#  ['Andorra', 'Luxembourg', 0.9973902910927477],
#  ['Andorra', 'MS Zaandam', 0.9238940615517974],
#  ['Andorra', 'Madagascar', 0.9863316287850277],
#  ['Andorra', 'Malawi', 0.8237872811835903],
#  ['Andorra', 'Malaysia', 0.9932322674076631],
#  ['Andorra', 'Maldives', 0.8561694629610419],
#  ['Andorra', 'Mali', 0.9319744074523512],
#  ['Andorra', 'Malta', 0.9863883994303374],
#  ['Andorra', 'Mauritania', 0.9826569455658133],
#  ['Andorra', 'Mauritius', 0.9846886579742267],
#  ['Andorra', 'Mexico', 0.9446033373445772],
#  ['Andorra', 'Moldova', 0.9348497121313266],
#  ['Andorra', 'Monaco', 0.9982269093681942],
#  ['Andorra', 'Mongolia', 0.9487085761295551],
#  ['Andorra', 'Montenegro', 0.9829307137085117],
#  ['Andorra', 'Morocco', 0.9760071101141518],
#  ['Andorra', 'Mozambique', 0.9686998671623194],
#  ['Andorra', 'Namibia', 0.9902760693448659],
#  ['Andorra', 'Nepal', 0.9783760075012481],
#  ['Andorra', 'Netherlands', 0.9961372481669581],
#  ['Andorra', 'New Zealand', 0.987876025000639],
#  ['Andorra', 'Nicaragua', 0.9904182841189163],
#  ['Andorra', 'Niger', 0.8501633483678301],
#  ['Andorra', 'Nigeria', 0.9854161392045981],
#  ['Andorra', 'North Macedonia', 0.9869459469239616],
#  ['Andorra', 'Norway', 0.9794914179516904],
#  ['Andorra', 'Oman', 0.9685728460013259],
#  ['Andorra', 'Pakistan', 0.9816946281210919],
#  ['Andorra', 'Panama', 0.9740395914991767],
#  ['Andorra', 'Papua New Guinea', 0.9445456357562029],
#  ['Andorra', 'Paraguay', 0.9953161449272112],
#  ['Andorra', 'Peru', 0.8707600846200495],
#  ['Andorra', 'Philippines', 0.9793982925577138],
#  ['Andorra', 'Poland', 0.975563474002216],
#  ['Andorra', 'Portugal', 0.988892828576202],
#  ['Andorra', 'Qatar', 0.9408478217528087],
#  ['Andorra', 'Romania', 0.975669921462655],
#  ['Andorra', 'Russia', 0.8876039338278077],
#  ['Andorra', 'Rwanda', 0.9982187391782873],
#  ['Andorra', 'Saint Kitts and Nevis', 0.9670821638386949],
#  ['Andorra', 'Saint Lucia', 0.9759668961699672],
#  ['Andorra', 'Saint Vincent and the Grenadines', 0.875283336733334],
#  ['Andorra', 'San Marino', 0.9405577276488147],
#  ['Andorra', 'Sao Tome and Principe', 0.7402975667491716],
#  ['Andorra', 'Saudi Arabia', 0.9793538033133662],
#  ['Andorra', 'Senegal', 0.997223389667342],
#  ['Andorra', 'Serbia', 0.9474960183236963],
#  ['Andorra', 'Seychelles', 0.9341629829046018],
#  ['Andorra', 'Sierra Leone', 0.866936278764575],
#  ['Andorra', 'Singapore', 0.9708165735909896],
#  ['Andorra', 'Slovakia', 0.9899289443184923],
#  ['Andorra', 'Slovenia', 0.9827273127083855],
#  ['Andorra', 'Somalia', 0.8719961017399642],
#  ['Andorra', 'South Africa', 0.9969093200009025],
#  ['Andorra', 'South Sudan', 0.7290963202509978],
#  ['Andorra', 'Spain', 0.9987125019299946],
#  ['Andorra', 'Sri Lanka', 0.9773398533681599],
#  ['Andorra', 'Sudan', 0.971945386275237],
#  ['Andorra', 'Suriname', 0.9571713139569364],
#  ['Andorra', 'Sweden', 0.9854414250344197],
#  ['Andorra', 'Switzerland', 0.9935715923107699],
#  ['Andorra', 'Syria', 0.9759336683976813],
#  ['Andorra', 'Taiwan*', 0.9728524648141078],
#  ['Andorra', 'Tanzania', 0.9870778988285701],
#  ['Andorra', 'Thailand', 0.9984468725364546],
#  ['Andorra', 'Timor-Leste', 0.9244115244909946],
#  ['Andorra', 'Togo', 0.9823046214375684],
#  ['Andorra', 'Trinidad and Tobago', 0.9807559696705397],
#  ['Andorra', 'Tunisia', 0.9945586937458275],
#  ['Andorra', 'Turkey', 0.9314259295391089],
#  ['Andorra', 'US', 0.9698787027139871],
#  ['Andorra', 'Uganda', 0.9884371477921016],
#  ['Andorra', 'Ukraine', 0.9335942421343035],
#  ['Andorra', 'United Arab Emirates', 0.9112293371426449],
#  ['Andorra', 'United Kingdom', 0.9633187256759246],
#  ['Andorra', 'Uruguay', 0.994679363038174],
#  ['Andorra', 'Uzbekistan', 0.917542562780729],
#  ['Andorra', 'Venezuela', 0.9808641960533395],
#  ['Andorra', 'Vietnam', 0.9733271509922145],
#  ['Andorra', 'West Bank and Gaza', 0.9810264024369542],
#  ['Andorra', 'Western Sahara', 0.7765240725821534],
#  ['Andorra', 'Yemen', 0.5062038014161662],
#  ['Andorra', 'Zambia', 0.9828266066572435],
#  ['Andorra', 'Zimbabwe', 0.9934935597594746],
#  ['Angola', 'Antigua and Barbuda', 0.9827489679647771],
#  ['Angola', 'Argentina', 0.9851912944971364],
#  ['Angola', 'Armenia', 0.9748817694748948],
#  ['Angola', 'Australia', 0.9488426487380431],
#  ['Angola', 'Austria', 0.9411872218972187],
#  ['Angola', 'Azerbaijan', 0.9862328973989468],
#  ['Angola', 'Bahamas', 0.9883072653265919],
#  ['Angola', 'Bahrain', 0.9348714959697558],
#  ['Angola', 'Bangladesh', 0.8593702958104659],
#  ['Angola', 'Barbados', 0.980814764322286],
#  ['Angola', 'Belarus', 0.8813888781360331],
#  ['Angola', 'Belgium', 0.9879802388494788],
#  ['Angola', 'Belize', 0.9624632993441699],
#  ['Angola', 'Benin', 0.985099033748287],
#  ['Angola', 'Bhutan', 0.9064719198838258],
#  ['Angola', 'Bolivia', 0.988159745950803],
#  ['Angola', 'Bosnia and Herzegovina', 0.9881869921550267],
#  ['Angola', 'Botswana', 0.9306531717312707],
#  ['Angola', 'Brazil', 0.9851473871896393],
#  ['Angola', 'Brunei', 0.8199700219470191],
#  ['Angola', 'Bulgaria', 0.961168273946647],
#  ['Angola', 'Burkina Faso', 0.9780983237961745],
#  ['Angola', 'Burma', 0.952634235623057],
#  ['Angola', 'Burundi', 0.9212235692791384],
#  ['Angola', 'Cabo Verde', 0.9219691465892913],
#  ['Angola', 'Cambodia', 0.8535337703614445],
#  ['Angola', 'Cameroon', 0.980046203278899],
#  ['Angola', 'Canada', 0.9922757433706105],
#  ['Angola', 'Central African Republic', 0.9453755997653863],
#  ['Angola', 'Chad', 0.9629434262613948],
#  ['Angola', 'Chile', 0.990338000483926],
#  ['Angola', 'China', 0.34057438658913114],
#  ['Angola', 'Colombia', 0.9871045997245784],
#  ['Angola', 'Congo (Brazzaville)', 0.985570346575302],
#  ['Angola', 'Congo (Kinshasa)', 0.983800520031688],
#  ['Angola', 'Costa Rica', 0.962483268126339],
#  ['Angola', "Cote d'Ivoire", 0.9845687329813606],
#  ['Angola', 'Croatia', 0.9750119727185241],
#  ['Angola', 'Cuba', 0.982264653110372],
#  ['Angola', 'Cyprus', 0.9856433307931439],
#  ['Angola', 'Czechia', 0.975347841928169],
#  ['Angola', 'Denmark', 0.9725135767269903],
#  ['Angola', 'Diamond Princess', 0.3589651714757689],
#  ['Angola', 'Djibouti', 0.9382098880801398],
#  ['Angola', 'Dominica', 0.9332131437771802],
#  ['Angola', 'Dominican Republic', 0.987377403945899],
#  ['Angola', 'Ecuador', 0.9692110063340691],
#  ['Angola', 'Egypt', 0.9858801587513335],
#  ['Angola', 'El Salvador', 0.9816140209562149],
#  ['Angola', 'Equatorial Guinea', 0.9194306913024867],
#  ['Angola', 'Eritrea', 0.9821291274168911],
#  ['Angola', 'Estonia', 0.9603162218054514],
#  ['Angola', 'Eswatini', 0.9331648874523559],
#  ['Angola', 'Ethiopia', 0.9884117694204115],
#  ['Angola', 'Fiji', 0.989756415318492],
#  ['Angola', 'Finland', 0.979181101672992],
#  ['Angola', 'France', 0.9926881825122822],
#  ['Angola', 'Gabon', 0.9745183852912939],
#  ['Angola', 'Gambia', 0.8921570212115231],
#  ['Angola', 'Georgia', 0.9747660761583024],
#  ['Angola', 'Germany', 0.9712353656762747],
#  ['Angola', 'Ghana', 0.9649236404667794],
#  ['Angola', 'Greece', 0.9486306067232015],
#  ['Angola', 'Grenada', 0.9475604676376145],
#  ['Angola', 'Guatemala', 0.9668664557189952],
#  ['Angola', 'Guinea', 0.9498163083590972],
#  ['Angola', 'Guinea-Bissau', 0.9649740170520112],
#  ['Angola', 'Guyana', 0.9585257727572624],
#  ['Angola', 'Haiti', 0.9889843413548576],
#  ['Angola', 'Holy See', 0.925032966531753],
#  ['Angola', 'Honduras', 0.9874139415865417],
#  ['Angola', 'Hungary', 0.979848595627978],
#  ['Angola', 'Iceland', 0.9461192529918622],
#  ['Angola', 'India', 0.9669474692839224],
#  ['Angola', 'Indonesia', 0.9858891274213792],
#  ['Angola', 'Iran', 0.9431806267121443],
#  ['Angola', 'Iraq', 0.9816146636462965],
#  ['Angola', 'Ireland', 0.9809795547153162],
#  ['Angola', 'Israel', 0.9833661302771569],
#  ['Angola', 'Italy', 0.9252913212580879],
#  ['Angola', 'Jamaica', 0.9601575062874681],
#  ['Angola', 'Japan', 0.9665236639783787],
#  ['Angola', 'Jordan', 0.9370558751720677],
#  ['Angola', 'Kazakhstan', 0.990800603622206],
#  ['Angola', 'Kenya', 0.988760022610697],
#  ['Angola', 'Korea, South', 0.6323761816442034],
#  ['Angola', 'Kosovo', 0.9657345898265025],
#  ['Angola', 'Kuwait', 0.9700455102904844],
#  ['Angola', 'Kyrgyzstan', 0.9833650175217797],
#  ['Angola', 'Laos', 0.9766829227309513],
#  ['Angola', 'Latvia', 0.9600643348615321],
#  ['Angola', 'Lebanon', 0.9135633392860584],
#  ['Angola', 'Liberia', 0.8965892872042582],
#  ['Angola', 'Libya', 0.983896198369986],
#  ['Angola', 'Liechtenstein', 0.8856309347017189],
#  ['Angola', 'Lithuania', 0.9817868721260613],
#  ['Angola', 'Luxembourg', 0.9542408681271334],
#  ['Angola', 'MS Zaandam', 0.925426488810557],
#  ['Angola', 'Madagascar', 0.9843340973593163],
#  ['Angola', 'Malawi', 0.9126568222312238],
#  ['Angola', 'Malaysia', 0.9550961130757862],
#  ['Angola', 'Maldives', 0.7724310491166104],
#  ['Angola', 'Mali', 0.9670607351119506],
#  ['Angola', 'Malta', 0.973119697213753],
#  ['Angola', 'Mauritania', 0.9228831367292557],
#  ['Angola', 'Mauritius', 0.9918665557196489],
#  ['Angola', 'Mexico', 0.9809505038472887],
#  ['Angola', 'Moldova', 0.982082806205101],
#  ['Angola', 'Monaco', 0.9716030225368558],
#  ['Angola', 'Mongolia', 0.8772330088314366],
#  ['Angola', 'Montenegro', 0.989129042590222],
#  ['Angola', 'Morocco', 0.9923926994620337],
#  ['Angola', 'Mozambique', 0.9647376079594452],
#  ['Angola', 'Namibia', 0.9427186940102019],
#  ['Angola', 'Nepal', 0.9733400990928792],
#  ['Angola', 'Netherlands', 0.9792253977676806],
#  ['Angola', 'New Zealand', 0.9869105415302266],
#  ['Angola', 'Nicaragua', 0.9649429275174815],
#  ['Angola', 'Niger', 0.9367154504745948],
#  ['Angola', 'Nigeria', 0.9871158239209592],
#  ['Angola', 'North Macedonia', 0.9885977355719093],
#  ['Angola', 'Norway', 0.9236931802536035],
#  ['Angola', 'Oman', 0.9849853231422051],
#  ['Angola', 'Pakistan', 0.9922236111397351],
#  ['Angola', 'Panama', 0.988708851818254],
#  ['Angola', 'Papua New Guinea', 0.9330968621087112],
#  ['Angola', 'Paraguay', 0.9817377549357157],
#  ['Angola', 'Peru', 0.9359759183518178],
#  ['Angola', 'Philippines', 0.9857179645424229],
#  ['Angola', 'Poland', 0.9921697638938453],
#  ['Angola', 'Portugal', 0.9863822249550516],
#  ['Angola', 'Qatar', 0.9737698546611595],
#  ['Angola', 'Romania', 0.9901366428283573],
#  ['Angola', 'Russia', 0.9488301692004488],
#  ['Angola', 'Rwanda', 0.9623854066612798],
#  ['Angola', 'Saint Kitts and Nevis', 0.9625384323182832],
#  ['Angola', 'Saint Lucia', 0.943258081018988],
#  ['Angola', 'Saint Vincent and the Grenadines', 0.9474321763709703],
#  ['Angola', 'San Marino', 0.8811008527062452],
#  ['Angola', 'Sao Tome and Principe', 0.8664878490075795],
#  ['Angola', 'Saudi Arabia', 0.9836449479504179],
#  ['Angola', 'Senegal', 0.9601012701436086],
#  ['Angola', 'Serbia', 0.9875878619377129],
#  ['Angola', 'Seychelles', 0.8608314880450981],
#  ['Angola', 'Sierra Leone', 0.949167755216145],
#  ['Angola', 'Singapore', 0.9711488692527065],
#  ['Angola', 'Slovakia', 0.976539858944671],
#  ['Angola', 'Slovenia', 0.9329752398090899],
#  ['Angola', 'Somalia', 0.9160975216155078],
#  ['Angola', 'South Africa', 0.9553124061644434],
#  ['Angola', 'South Sudan', 0.8455890366370289],
#  ['Angola', 'Spain', 0.9715373203286126],
#  ['Angola', 'Sri Lanka', 0.9250397912900156],
#  ['Angola', 'Sudan', 0.9863658120514774],
#  ['Angola', 'Suriname', 0.8759121303043047],
#  ['Angola', 'Sweden', 0.9801692304343564],
#  ['Angola', 'Switzerland', 0.9476745882216565],
#  ['Angola', 'Syria', 0.9745212026022132],
#  ['Angola', 'Taiwan*', 0.9048408731815256],
#  ['Angola', 'Tanzania', 0.9507078367064218],
#  ['Angola', 'Thailand', 0.9619625329155786],
#  ['Angola', 'Timor-Leste', 0.8733821808141196],
#  ['Angola', 'Togo', 0.9887443738913461],
#  ['Angola', 'Trinidad and Tobago', 0.9207863976400018],
#  ['Angola', 'Tunisia', 0.9785724490530793],
#  ['Angola', 'Turkey', 0.9772163839171906],
#  ['Angola', 'US', 0.9911509937832079],
#  ['Angola', 'Uganda', 0.9506161288832422],
#  ['Angola', 'Ukraine', 0.9706641153315635],
#  ['Angola', 'United Arab Emirates', 0.9686777883576105],
#  ['Angola', 'United Kingdom', 0.9885835841070719],
#  ['Angola', 'Uruguay', 0.9476425538626365],
#  ['Angola', 'Uzbekistan', 0.972229363300245],
#  ['Angola', 'Venezuela', 0.9173465300739445],
#  ['Angola', 'Vietnam', 0.9077915792297326],
#  ['Angola', 'West Bank and Gaza', 0.9778057585081155],
#  ['Angola', 'Western Sahara', 0.8929378316026433],
#  ['Angola', 'Yemen', 0.578083878835138],
#  ['Angola', 'Zambia', 0.9257017152934882],
#  ['Angola', 'Zimbabwe', 0.9674599374571505],
#  ['Antigua and Barbuda', 'Argentina', 0.988903328020198],
#  ['Antigua and Barbuda', 'Armenia', 0.9828068758960041],
#  ['Antigua and Barbuda', 'Australia', 0.96058324203741],
#  ['Antigua and Barbuda', 'Austria', 0.9543691873440382],
#  ['Antigua and Barbuda', 'Azerbaijan', 0.9777798348563665],
#  ['Antigua and Barbuda', 'Bahamas', 0.9872496407938179],
#  ['Antigua and Barbuda', 'Bahrain', 0.948175855883853],
#  ['Antigua and Barbuda', 'Bangladesh', 0.8406969033991134],
#  ['Antigua and Barbuda', 'Barbados', 0.9863712280270438],
#  ['Antigua and Barbuda', 'Belarus', 0.8631068008868371],
#  ['Antigua and Barbuda', 'Belgium', 0.9894461331612433],
#  ['Antigua and Barbuda', 'Belize', 0.9524351019027809],
#  ['Antigua and Barbuda', 'Benin', 0.9771811342740819],
#  ['Antigua and Barbuda', 'Bhutan', 0.9228398772085845],
#  ['Antigua and Barbuda', 'Bolivia', 0.9813654326603749],
#  ['Antigua and Barbuda', 'Bosnia and Herzegovina', 0.9895887533092761],
#  ['Antigua and Barbuda', 'Botswana', 0.9084341040726219],
#  ['Antigua and Barbuda', 'Brazil', 0.9787165224552247],
#  ['Antigua and Barbuda', 'Brunei', 0.84346041130878],
#  ['Antigua and Barbuda', 'Bulgaria', 0.969924560758609],
#  ['Antigua and Barbuda', 'Burkina Faso', 0.9807844675934737],
#  ['Antigua and Barbuda', 'Burma', 0.9597782894276525],
#  ['Antigua and Barbuda', 'Burundi', 0.9315054524285081],
#  ['Antigua and Barbuda', 'Cabo Verde', 0.9305102162263545],
#  ['Antigua and Barbuda', 'Cambodia', 0.8695433170955728],
#  ['Antigua and Barbuda', 'Cameroon', 0.9801059332119344],
#  ['Antigua and Barbuda', 'Canada', 0.9889603940697621],
#  ['Antigua and Barbuda', 'Central African Republic', 0.9649842745633268],
#  ['Antigua and Barbuda', 'Chad', 0.9680867743128415],
#  ['Antigua and Barbuda', 'Chile', 0.9893533169910989],
#  ['Antigua and Barbuda', 'China', 0.356964477909417],
#  ['Antigua and Barbuda', 'Colombia', 0.9837375791040883],
#  ['Antigua and Barbuda', 'Congo (Brazzaville)', 0.961274847940738],
#  ['Antigua and Barbuda', 'Congo (Kinshasa)', 0.9870354931080747],
#  ['Antigua and Barbuda', 'Costa Rica', 0.9711503917115262],
#  ['Antigua and Barbuda', "Cote d'Ivoire", 0.9776464531939985],
#  ['Antigua and Barbuda', 'Croatia', 0.9813294996099173],
#  ['Antigua and Barbuda', 'Cuba', 0.9747509272009809],
#  ['Antigua and Barbuda', 'Cyprus', 0.9892459304208274],
#  ['Antigua and Barbuda', 'Czechia', 0.9818725136583059],
#  ['Antigua and Barbuda', 'Denmark', 0.9785364211128131],
#  ['Antigua and Barbuda', 'Diamond Princess', 0.3770196037490949],
#  ['Antigua and Barbuda', 'Djibouti', 0.9211612912042191],
#  ['Antigua and Barbuda', 'Dominica', 0.9498155471285158],
#  ['Antigua and Barbuda', 'Dominican Republic', 0.9846200763918048],
#  ['Antigua and Barbuda', 'Ecuador', 0.9688072174492849],
#  ['Antigua and Barbuda', 'Egypt', 0.9854529402972116],
#  ['Antigua and Barbuda', 'El Salvador', 0.9706314521938583],
#  ['Antigua and Barbuda', 'Equatorial Guinea', 0.9360010037304033],
#  ['Antigua and Barbuda', 'Eritrea', 0.9834140715999969],
#  ['Antigua and Barbuda', 'Estonia', 0.973262541748143],
#  ['Antigua and Barbuda', 'Eswatini', 0.9444273587074792],
#  ['Antigua and Barbuda', 'Ethiopia', 0.9855032929807898],
#  ['Antigua and Barbuda', 'Fiji', 0.9869505044681124],
#  ['Antigua and Barbuda', 'Finland', 0.9815352290351522],
#  ['Antigua and Barbuda', 'France', 0.9912317019344337],
#  ['Antigua and Barbuda', 'Gabon', 0.9666146111405097],
#  ['Antigua and Barbuda', 'Gambia', 0.9086700583777071],
#  ['Antigua and Barbuda', 'Georgia', 0.9817477429313164],
#  ['Antigua and Barbuda', 'Germany', 0.9793329712028581],
#  ['Antigua and Barbuda', 'Ghana', 0.9676107485743745],
#  ['Antigua and Barbuda', 'Greece', 0.9614321523383418],
#  ['Antigua and Barbuda', 'Grenada', 0.9674270008719142],
#  ['Antigua and Barbuda', 'Guatemala', 0.9620823487618543],
#  ['Antigua and Barbuda', 'Guinea', 0.9389506941272172],
#  ['Antigua and Barbuda', 'Guinea-Bissau', 0.9548051512559965],
#  ['Antigua and Barbuda', 'Guyana', 0.9512551264634602],
#  ['Antigua and Barbuda', 'Haiti', 0.9844291109388335],
#  ['Antigua and Barbuda', 'Holy See', 0.9413890041103481],
#  ['Antigua and Barbuda', 'Honduras', 0.9866083773210047],
#  ['Antigua and Barbuda', 'Hungary', 0.9799671874522178],
#  ['Antigua and Barbuda', 'Iceland', 0.9570438630596058],
#  ['Antigua and Barbuda', 'India', 0.9524175848482374],
#  ['Antigua and Barbuda', 'Indonesia', 0.9852380593923562],
#  ['Antigua and Barbuda', 'Iran', 0.9554753972742533],
#  ['Antigua and Barbuda', 'Iraq', 0.9842918744133755],
#  ['Antigua and Barbuda', 'Ireland', 0.9811847052072207],
#  ['Antigua and Barbuda', 'Israel', 0.9881502147146562],
#  ['Antigua and Barbuda', 'Italy', 0.9389121907880965],
#  ['Antigua and Barbuda', 'Jamaica', 0.9690741708546382],
#  ['Antigua and Barbuda', 'Japan', 0.9666174004534133],
#  ['Antigua and Barbuda', 'Jordan', 0.9499624232651418],
#  ['Antigua and Barbuda', 'Kazakhstan', 0.9865809849665756],
#  ['Antigua and Barbuda', 'Kenya', 0.9879087466673359],
#  ['Antigua and Barbuda', 'Korea, South', 0.6572988123398249],
#  ['Antigua and Barbuda', 'Kosovo', 0.970813505379581],
#  ['Antigua and Barbuda', 'Kuwait', 0.9624719316623753],
#  ['Antigua and Barbuda', 'Kyrgyzstan', 0.9711964688335593],
#  ['Antigua and Barbuda', 'Laos', 0.980007485232607],
#  ['Antigua and Barbuda', 'Latvia', 0.96957071085902],
#  ...]

# %%
country
# Out:
# 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                 Andorra
# 4                  Angola
#               ...
# 180    West Bank and Gaza
# 181        Western Sahara
# 182                 Yemen
# 183                Zambia
# 184              Zimbabwe
# Name: Unnamed: 0, Length: 185, dtype: object

# %%
statistics.variance(a)
# Out:
# 22113.344323998794

# %%
b = [1, 1, 1]
statistics.variance(b)
# Out:
# 0

# %%
aa = [1,1]
bb = []
for i in range(3):
    bb.append(aa)
    bb.append([2])

# %%
bb
std[1]
# Out:
# 134.1858966620303

# %%
aaa = np.cov(origin_data_numonly.iloc[0], origin_data_numonly.iloc[2])
aaa[0, 1]
# Out:
# 76963.54381210476

# %%
aaa
# Out:
# array([[ 22113.344324  ,  76963.5438121 ],
#        [ 76963.5438121 , 270394.49081602]])

# %%
for i in range(5):
    for j in range(i + 1, 5, 1):
        print(i, j)
# Out:
# 0 1
# 0 2
# 0 3
# 0 4
# 1 2
# 1 3
# 1 4
# 2 3
# 2 4
# 3 4
